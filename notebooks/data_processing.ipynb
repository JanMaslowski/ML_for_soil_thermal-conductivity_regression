# %%
import pandas as pd
import numpy as np
import sweetviz as sv

data_path = 'data_processed/data_1_2.csv'
parent_path = '/Users/janmaslowski/Desktop/ML_soil/ML_for_soil_thermal-conductivity_regression/'

# %%
data = pd.read_csv(parent_path+data_path)
data.drop("Unnamed: 0",axis=1,inplace=True)
data
# Out:
#         id       n  ro_d       sr  k_sat  k_dry        k    qr     cl     si  \
# 0      1.0  0.5100  1.32  0.00000    1.2   0.21  0.21000  0.21  0.418  0.582
# 1      1.0  0.5100  1.32  0.10000    1.2   0.21  0.28000  0.21  0.418  0.582
# 2      1.0  0.5100  1.32  0.25000    1.2   0.21  0.41000  0.21  0.418  0.582
# 3      1.0  0.5100  1.32  0.50000    1.2   0.21  0.71000  0.21  0.418  0.582
# 4      1.0  0.5100  1.32  0.75000    1.2   0.21  0.88000  0.21  0.418  0.582
# ..     ...     ...   ...      ...    ...    ...      ...   ...    ...    ...
# 952  151.0  0.3962  1.60  0.19636    NaN    NaN  1.89301  1.00  0.000  0.000
# 953  151.0  0.3962  1.60  0.39273    NaN    NaN  2.31063  1.00  0.000  0.000
# 954  151.0  0.3962  1.60  0.58909    NaN    NaN  2.57822  1.00  0.000  0.000
# 955  151.0  0.3962  1.60  0.78545    NaN    NaN  2.71193  1.00  0.000  0.000
# 956  151.0  0.3962  1.60  0.98182    NaN    NaN  2.85607  1.00  0.000  0.000
#
# ...

# %%
unique_val = []

# Sprawdzenie, czy wartości są unikalne
for value in data["sr"]:
    unique_val.append(value)

# Usunięcie duplikatów za pomocą set i posortowanie wyników
val = sorted(set(unique_val))

print(val)
# Out:
# [0.0, 0.01, 0.0237, 0.03, 0.0346, 0.04, 0.0473, 0.05, 0.06, 0.0691, 0.07, 0.071, 0.08, 0.09, 0.0947, 0.1, 0.1037, 0.11, 0.1184, 0.12, 0.13, 0.14, 0.142, 0.14286, 0.16, 0.1657, 0.16667, 0.17, 0.1728, 0.18, 0.1894, 0.19323, 0.19636, 0.19643, 0.2, 0.2074, 0.20833, 0.21, 0.2131, 0.22, 0.22609, 0.23, 0.2367, 0.24, 0.2419, 0.25, 0.26, 0.2604, 0.27, 0.28, 0.2841, 0.29, 0.3, 0.31, 0.32, 0.33, 0.3314, 0.34, 0.3456, 0.35, 0.3551, 0.35714, 0.36, 0.3788, 0.38, 0.39, 0.39273, 0.39286, 0.4, 0.4025, 0.41, 0.41407, 0.41667, 0.4261, 0.43, 0.44, 0.4498, 0.45217, 0.46, 0.47, 0.4735, 0.48, 0.49, 0.5, 0.5019, 0.52, 0.5208, 0.53, 0.54, 0.5445, 0.55, 0.56, 0.57, 0.57143, 0.58, 0.58909, 0.58929, 0.5919, 0.6, 0.60731, 0.61, 0.6155, 0.62, 0.625, 0.65, 0.66667, 0.67, 0.67826, 0.7, 0.72, 0.73, 0.74, 0.75, 0.78545, 0.78571, 0.8, 0.80054, 0.81, 0.83333, 0.85, 0.86, 0.90435, 0.92, 0.93, 0.94, 0.95, 0.98, 0.98182, 0.98214, 0.99377, 1.0, 1.01739, 1.04167]
